# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
datos = pd.read_csv('https://raw.githubusercontent.com/juanrod1028/ComputacionParalela/master/Clases/Corte3/TallerCyton/resultados.csv')

# %%
plt.rcParams['figure.figsize']=[16,8]
plt.title("Comparativa de rendimiento entre python y cython")
plt.plot(datos["n_steps"],datos['tiempo_python'])
plt.plot(datos["n_steps"],datos['tiempo_cython'])
plt.legend(["python","cython"])
plt.xlabel("Número de pasos")
plt.ylabel("Tiempo (Seg)")
plt.grid()
plt.show()
