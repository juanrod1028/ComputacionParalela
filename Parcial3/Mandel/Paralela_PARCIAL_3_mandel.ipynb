# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
datos = pd.read_csv('https://raw.githubusercontent.com/juanrod1028/ComputacionParalela/master/Parcial3/Mandel/resultados.csv')

# %%
datos
# Out:
#     n_steps  tiempo_python  tiempo_cython    speedup
# 0       100       0.146829       0.002720  53.983783
# 1       200       0.633808       0.010796  58.705982
# 2       300       1.413105       0.023205  60.897726
# 3       400       2.440296       0.041284  59.110201
# 4       500       3.889302       0.066225  58.728350
# 5       600       5.717980       0.098125  58.272699
# 6       700       7.641539       0.132735  57.569779
# 7       800       9.896290       0.182337  54.274778
# 8       900      12.524809       0.217135  57.682015
# 9      1000      15.273934       0.264231  57.805289
# 10     1100      18.365902       0.312759  58.722231
# 11     1200      22.189066       0.385530  57.554780

# %%
plt.rcParams['figure.figsize']=[16,8]
plt.title("Comparativa de rendimiento entre python y cython")
plt.plot(datos["n_steps"],datos['tiempo_python'])
plt.plot(datos["n_steps"],datos['tiempo_cython'])
plt.legend(["python","cython"])
plt.xlabel("Número de pasos")
plt.ylabel("Tiempo (Seg)")
plt.grid()
plt.show()

# %%
plt.rcParams['figure.figsize']=[16,8]
plt.title("Comparativa de rendimiento entre python y cython")
plt.plot(datos["n_steps"],datos['speedup'])
plt.legend(["python/cython"])
plt.xlabel("Número de pasos")
plt.ylabel("Tiempo (Seg)")
plt.grid()
plt.show()
